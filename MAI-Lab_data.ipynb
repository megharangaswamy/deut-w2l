# %%
import webvtt
from os import listdir
from os.path import isfile, join
import pandas as pd
from pydub import AudioSegment
import os
import codecs
import shutil
import natsort 
import wave

# %%
rootdir= "/media/home/megha/6_zamia/de_DE_MAI/de_DE/by_book"
rootdir1 = "/home/megha/Desktop/b"
#1) ---------------------------------------- checking specification and renaming to .flac----------------
if False:
    for Dir in natsort.natsorted(os.listdir(rootdir)):
        if(Dir[-4:] != ".txt"):
            if(Dir != "mix"):
                #print(Dir)
                for subDir in natsort.natsorted(os.listdir(rootdir+"/"+Dir)):
                    #print(subDir)
                    for subsubDir in natsort.natsorted(os.listdir(rootdir+"/"+Dir+"/"+subDir)):
                        #print(subsubDir)
                        if(subsubDir[-4:] != ".txt"):
                            for wav in natsort.natsorted(os.listdir(rootdir+"/"+Dir+"/"+subDir+"/"+subsubDir)):
                                if(wav == "wavs"):
                                    for file in natsort.natsorted(os.listdir(rootdir+"/"+Dir+"/"+subDir+"/"+subsubDir+"/"+wav)):
                                        #-----------------------check audio specification----------------------
                                        
                                        #f = wave.open(rootdir+"/"+Dir+"/"+subDir+"/"+subsubDir+"/"+wav+"/"+file, 'r')
                                        #print(f.getnchannels()) #Returns number of audio channels (1 for mono, 2 for stereo).
                                        #print(f.getframerate()) #Returns sampling frequency.
                                        os.rename(rootdir+"/"+Dir+"/"+subDir+"/"+subsubDir+"/"+wav+"/"+file,rootdir+"/"+Dir+"/"+subDir+"/"+subsubDir+"/"+wav+"/"+file[:-4]+".flac")
            if(Dir == "mix"):
                for subDir in natsort.natsorted(os.listdir(rootdir+"/"+Dir)):                    
                    if(subDir[-4:] != ".txt"):
                        #print(subDir)
                        for wav in natsort.natsorted(os.listdir(rootdir+"/"+Dir+"/"+subDir)):
                                    if(wav == "wavs"):
                                        for file in natsort.natsorted(os.listdir(rootdir+"/"+Dir+"/"+subDir+"/"+wav)):
                                            #-----------------------check audio specification----------------------
                                            
                                            #f = wave.open(rootdir+"/"+Dir+"/"+subDir+"/"+wav+"/"+file, 'r')
                                            #print(f.getnchannels()) #Returns number of audio channels (1 for mono, 2 for stereo).
                                            #print(f.getframerate()) #Returns sampling frequency.
                                            os.rename(rootdir+"/"+Dir+"/"+subDir+"/"+wav+"/"+file,rootdir+"/"+Dir+"/"+subDir+"/"+wav+"/"+file[:-4]+".flac")

#2) -----------------------------------------extracting trans.txt file---------------------------------------
if False:
    for Dir in natsort.natsorted(os.listdir(rootdir)):
        if(Dir[-4:] != ".txt"):
            if(Dir != "mix"):
                for subDir in natsort.natsorted(os.listdir(rootdir+"/"+Dir)):
                    for subsubDir in natsort.natsorted(os.listdir(rootdir+"/"+Dir+"/"+subDir)):
                        if(subsubDir[-4:] != ".txt"):
                            for csv in natsort.natsorted(os.listdir(rootdir+"/"+Dir+"/"+subDir+"/"+subsubDir)):
                                if(csv.endswith(".csv")):
                                    with codecs.open(rootdir+"/"+Dir+"/"+subDir+"/"+subsubDir+"/"+csv, 'r', encoding='utf8') as f:
                                        with open(rootdir+"/"+Dir+"/"+subDir+"/"+subsubDir+"/wavs/metadata.trans.txt", "a") as write_file:
                                            line = f.readline()
                                            cnt = 1
                                            while line:
                                                each_line = line.strip()
                                                split_each_line = each_line.split('|')
                                                text = split_each_line[-1].replace("- ", "")
                                                write_file.write(split_each_line[0]+" "+text.upper()+"\n")
                                                line = f.readline()  
                                                cnt += 1
            if(Dir == "mix"):
                for subDir in natsort.natsorted(os.listdir(rootdir+"/"+Dir)):                    
                    if(subDir[-4:] != ".txt"):
                        for csv in natsort.natsorted(os.listdir(rootdir+"/"+Dir+"/"+subDir)):
                            if(csv.endswith(".csv")):
                                with codecs.open(rootdir+"/"+Dir+"/"+subDir+"/"+csv, 'r', encoding='utf8') as f:
                                    with open(rootdir+"/"+Dir+"/"+subDir+"/wavs/metadata.trans.txt", "a") as write_file:
                                        line = f.readline()
                                        cnt = 1
                                        while line:
                                            each_line = line.strip()
                                            split_each_line = each_line.split('|')
                                            text = split_each_line[-1].replace("- ", "")
                                            write_file.write(split_each_line[0]+" "+text.upper()+"\n")
                                            line = f.readline()  
                                            cnt += 1
#3) -------------------------------------------------------cleaning the files-----------------------------------------
if False:
    for Dir in natsort.natsorted(os.listdir(rootdir)):
        if(Dir[-4:] == ".txt"):
            os.remove(rootdir+"/"+Dir)
        if(Dir[-4:] != ".txt"):
            if(Dir != "mix"):
                for subDir in natsort.natsorted(os.listdir(rootdir+"/"+Dir)):                    
                    for subsubDir in natsort.natsorted(os.listdir(rootdir+"/"+Dir+"/"+subDir)):
                        if(subsubDir[-4:] == ".txt"):
                            os.remove(rootdir+"/"+Dir+"/"+subDir+"/"+subsubDir)
                        if(subsubDir[-4:] != ".txt"):
                            for meta in natsort.natsorted(os.listdir(rootdir+"/"+Dir+"/"+subDir+"/"+subsubDir)):
                                if(meta != "wavs"):
                                    os.remove(rootdir+"/"+Dir+"/"+subDir+"/"+subsubDir+"/"+meta)                               
            if(Dir == "mix"):
                for subDir in natsort.natsorted(os.listdir(rootdir+"/"+Dir)):
                    if(subDir[-4:] == ".txt"):
                        os.remove(rootdir+"/"+Dir+"/"+subDir)
                    if(subDir[-4:] != ".txt"):
                        for meta in natsort.natsorted(os.listdir(rootdir+"/"+Dir+"/"+subDir)):
                            if(meta != "wavs"):
                                os.remove(rootdir+"/"+Dir+"/"+subDir+"/"+meta)
                                
#4) ---------------------- creating structure according to wav2letter pipe line----------------------------------

#before that, create a folder called Munich_AI_data and 3 sub-folders called dev-clean, test-clean, train-clean-100

if False:
    for Dir in natsort.natsorted(os.listdir(rootdir)):
        if(Dir != "mix"):
            for subDir in natsort.natsorted(os.listdir(rootdir+"/"+Dir)):       
                for subsubDir in natsort.natsorted(os.listdir(rootdir+"/"+Dir+"/"+subDir)):
                    for wav in natsort.natsorted(os.listdir(rootdir+"/"+Dir+"/"+subDir+"/"+subsubDir)):
                        for file in natsort.natsorted(os.listdir(rootdir+"/"+Dir+"/"+subDir+"/"+subsubDir+"/"+wav)):
                            shutil.move(rootdir+"/"+Dir+"/"+subDir+"/"+subsubDir+"/"+wav+"/"+file, rootdir+"/"+Dir+"/"+subDir+"/"+subsubDir+"/"+file)
                        os.rmdir(rootdir+"/"+Dir+"/"+subDir+"/"+subsubDir+"/"+wav)
        if(Dir == "mix"):
            for subDir in natsort.natsorted(os.listdir(rootdir+"/"+Dir)):
                for wav in natsort.natsorted(os.listdir(rootdir+"/"+Dir+"/"+subDir)):
                    for file in natsort.natsorted(os.listdir(rootdir+"/"+Dir+"/"+subDir+"/"+wav)):
                        shutil.move(rootdir+"/"+Dir+"/"+subDir+"/"+wav+"/"+file, rootdir+"/"+Dir+"/"+subDir+"/"+file)
                    os.rmdir(rootdir+"/"+Dir+"/"+subDir+"/"+wav)
        
    
# now reaggange the folders .
