# %%
import webvtt
from os import listdir
from os.path import isfile, join
import pandas as pd
from pydub import AudioSegment
import os
import shutil
import natsort 

import xml.etree.ElementTree as ET

# %%
# 1)--------------------------------check audio file specification----------------------------------------------------
if False:  #True   False
    #check wav file specifications
    import wave
    rootdir1 = '/media/home/megha/5_wav2letter/WAV_2_LETTER/wav2letter/tutorials/0_deutsch_data/Dataset_1_foxForge-tuda-de/german-speechdata-package-v2/train'

    for files in natsort.natsorted(os.listdir(rootdir1)):
        if(files.endswith(".wav")):
            print(files)
            print('--------------------------------------------------')
            f = wave.open(rootdir1+"/"+files, 'r')
            print(f.getnchannels()) #Returns number of audio channels (1 for mono, 2 for stereo).
            #print(f.getsampwidth())
            print(f.getframerate()) #Returns sampling frequency.

# 2)-----------------------------------renaming into flac file--------------------------------------------------------

if False:    #True   False
    import wave
    import shutil    
    train = '/media/home/megha/5_wav2letter/WAV_2_LETTER/wav2letter/tutorials/0_deutsch_data/Dataset_1_foxForge-tuda-de/german-speechdata-package-v2/train'
    test = '/media/home/megha/5_wav2letter/WAV_2_LETTER/wav2letter/tutorials/0_deutsch_data/Dataset_1_foxForge-tuda-de/german-speechdata-package-v2/test'
    dev = '/media/home/megha/5_wav2letter/WAV_2_LETTER/wav2letter/tutorials/0_deutsch_data/Dataset_1_foxForge-tuda-de/german-speechdata-package-v2/dev'
    
    rootdir1 = '/media/home/megha/5_wav2letter/WAV_2_LETTER/wav2letter/tutorials/0_deutsch_data/Dataset_1_foxForge-tuda-de/german-speechdata-package-v2/train'
    rootdir = rootdir1
    for file in natsort.natsorted(os.listdir(rootdir)):
        if(file.endswith(".wav")):
            os.rename(rootdir+"/"+file,rootdir+"/"+file[:-4]+".flac")

# 3)-----------------------------------creating folder and moving corresponding files inside--------------------------
if False:   #True   False
    train = '/media/home/megha/5_wav2letter/WAV_2_LETTER/wav2letter/tutorials/0_deutsch_data/Dataset_1_foxForge-tuda-de/german-speechdata-package-v2/train'
    test = '/media/home/megha/5_wav2letter/WAV_2_LETTER/wav2letter/tutorials/0_deutsch_data/Dataset_1_foxForge-tuda-de/german-speechdata-package-v2/test'
    dev = '/media/home/megha/5_wav2letter/WAV_2_LETTER/wav2letter/tutorials/0_deutsch_data/Dataset_1_foxForge-tuda-de/german-speechdata-package-v2/dev'
   
    rootdir1 = '/media/home/megha/5_wav2letter/WAV_2_LETTER/wav2letter/tutorials/0_deutsch_data/Dataset_1_foxForge-tuda-de/german-speechdata-package-v2/train'
    rootdir = rootdir1
    for file in natsort.natsorted(os.listdir(rootdir)):
        #print(file)    
        if(file.endswith(".xml")):
            folder_name = file[:-4]
            if not os.path.exists(rootdir+"/"+folder_name):
                os.makedirs(rootdir+"/"+folder_name)
            for file1 in natsort.natsorted(os.listdir(rootdir)):
                if(file1.endswith(".flac") or file1.endswith(".xml")):
                    if(file1[:-4] == folder_name or file1.split('_')[0] == folder_name):
                        shutil.move(rootdir+"/"+file1, rootdir+"/"+folder_name)

# 4)-----------------------------------extracting transcript into .trans.txt file------------------------------------

                        
if False:  #True   False
    train = '/media/home/megha/5_wav2letter/WAV_2_LETTER/wav2letter/tutorials/0_deutsch_data/Dataset_1_foxForge-tuda-de/german-speechdata-package-v2/train'
    test = '/media/home/megha/5_wav2letter/WAV_2_LETTER/wav2letter/tutorials/0_deutsch_data/Dataset_1_foxForge-tuda-de/german-speechdata-package-v2/test'
    dev = '/media/home/megha/5_wav2letter/WAV_2_LETTER/wav2letter/tutorials/0_deutsch_data/Dataset_1_foxForge-tuda-de/german-speechdata-package-v2/dev'
    
    rootdir1 = '/media/home/megha/5_wav2letter/WAV_2_LETTER/wav2letter/tutorials/0_deutsch_data/Dataset_1_foxForge-tuda-de/german-speechdata-package-v2/train'
    rootdir = rootdir1
    
    for Dir in natsort.natsorted(os.listdir(rootdir)):
        text = ""
        file_name = ""
        for file in natsort.natsorted(os.listdir(rootdir+"/"+Dir)):
            #print(file)
            if(file.endswith(".xml")):
                file_name = file[:-4]
                tree = ET.parse(rootdir+"/"+Dir+"/"+file)
                root = tree.getroot()
                for sentence in root.iter('cleaned_sentence'):
                        text = sentence.text.upper()
                        #print(text)
                os.remove(rootdir+"/"+Dir+"/"+file)
            else:
                audio_file_name = file[:-5]
                with open(rootdir+"/"+Dir+"/"+file_name+".trans.txt", "a") as file:
                    file.write(audio_file_name+" "+text+"\n")
            
            
                
        print('-----------------------------------------------------------------------------')
# Out:
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
# ...
