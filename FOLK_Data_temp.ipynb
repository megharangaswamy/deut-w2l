# %%
import webvtt
from os import listdir
from os.path import isfile, join
import pandas as pd
from pydub import AudioSegment
import os
import shutil
import natsort 
import wave
import xml.etree.ElementTree as ET

# %%
root = "/media/home/megha/5_wav2letter/WAV_2_LETTER/wav2letter/tutorials/0_deutsch_data/Datset_Uni/FOLK/DGD-Download_3617D0878D90D0A23A44D6875D3EB642_1553175816381/"

# %%
rootdir = "/home/megha/Desktop/c/DGD-Download_3617D0878D90D0A23A44D6875D3EB642_1553176432773"

tree = ET.parse(rootdir+"/FOLK_E_00190_SE_01_T_01.fln")
root = tree.getroot()
df  = pd.DataFrame(columns = ['A', 'B', 'C'])
for contribution in root.findall("./contribution"):
    #time = contribution.attrib['time']    
    #print(contribution.tag)
    children = contribution.getchildren()    
    time_array = []  
    word = ""
    for child in children:        
        #print(child.tag)
        if(child.tag == "time"):
            #print(child.attrib['time'])
            time_array.append(child.attrib['time'])  
        if(child.tag == "w"):
            #print(child.text)
            word = word+" "+child.text
        df2 = pd.DataFrame([[time_array[0],time_array[-1],word]], columns=list('ABC'))  
    print('--------------------------------------------------------------------')
    df = df.append(df2)    
#print(df)    
df = df.rename(index=str, columns={"A": "start", "B": "end","C" : "text"})
# Out:
# time
# pause
# time
# --------------------------------------------------------------------
# time
# non-phonological
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# breathe
# time
# w
# time
# --------------------------------------------------------------------
# time
# non-phonological
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# time
# breathe
# pause
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# w
# w
# time
# breathe
# pause
# time
# w
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# pause
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# pause
# w
# time
# --------------------------------------------------------------------
# time
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# breathe
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# breathe
# pause
# time
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# time
# breathe
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# breathe
# time
# w
# w
# w
# w
# w
# w
# w
# time
# breathe
# time
# w
# w
# w
# w
# w
# w
# time
# pause
# breathe
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# breathe
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# w
# w
# w
# w
# breathe
# time
# w
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# time
# --------------------------------------------------------------------
# time
# w
# time
# --------------------------------------------------------------------
# time
# breathe
# time
# w
# pause
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# breathe
# time
# w
# w
# w
# w
# w
# pause
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# breathe
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# pause
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# non-phonological
# pause
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# breathe
# time
# w
# w
# w
# pause
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# breathe
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# breathe
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# breathe
# time
# w
# pause
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# w
# w
# breathe
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# breathe
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# breathe
# non-phonological
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# breathe
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# breathe
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# breathe
# pause
# w
# w
# w
# w
# w
# pause
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# time
# w
# w
# w
# w
# pause
# w
# w
# w
# breathe
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# pause
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# pause
# w
# w
# w
# w
# w
# w
# pause
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# non-phonological
# time
# w
# w
# w
# w
# w
# time
# w
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# breathe
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# breathe
# time
# w
# w
# w
# time
# w
# w
# w
# w
# w
# w
# time
# w
# w
# time
# w
# time
# --------------------------------------------------------------------
# time
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# breathe
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# pause
# time
# w
# w
# w
# w
# w
# time
# breathe
# time
# w
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# breathe
# time
# w
# w
# pause
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# breathe
# time
# w
# time
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# non-phonological
# breathe
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# w
# w
# w
# w
# w
# time
# breathe
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# w
# w
# breathe
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# breathe
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# breathe
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# w
# time
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# breathe
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# breathe
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# non-phonological
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# breathe
# time
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# breathe
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# breathe
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# breathe
# time
# --------------------------------------------------------------------
# time
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# pause
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# time
# w
# time
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# non-phonological
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# time
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# non-phonological
# breathe
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# time
# --------------------------------------------------------------------
# time
# breathe
# pause
# time
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# w
# w
# w
# w
# breathe
# time
# w
# w
# pause
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# breathe
# time
# w
# pause
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# breathe
# time
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# pause
# time
# --------------------------------------------------------------------
# time
# w
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# breathe
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# non-phonological
# breathe
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# breathe
# time
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# breathe
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# breathe
# time
# w
# w
# w
# w
# pause
# w
# w
# w
# w
# w
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# breathe
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# breathe
# w
# w
# w
# w
# w
# w
# w
# pause
# w
# w
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# w
# w
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# time
# pause
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# time
# --------------------------------------------------------------------
# time
# non-phonological
# time
# breathe
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# breathe
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# w
# w
# time
# w
# w
# w
# w
# w
# breathe
# time
# w
# w
# w
# pause
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# w
# w
# pause
# w
# w
# time
# breathe
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# time
# w
# w
# w
# w
# time
# w
# w
# w
# w
# w
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# non-phonological
# breathe
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# breathe
# pause
# time
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# breathe
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# w
# w
# w
# time
# breathe
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# breathe
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# breathe
# time
# w
# pause
# w
# pause
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# pause
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# non-phonological
# breathe
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# time
# pause
# breathe
# time
# w
# w
# w
# w
# w
# pause
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# pause
# time
# breathe
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# pause
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# breathe
# time
# w
# w
# w
# w
# w
# w
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# time
# w
# w
# w
# time
# w
# w
# time
# breathe
# time
# w
# w
# pause
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# w
# w
# w
# pause
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# pause
# w
# w
# w
# time
# breathe
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# w
# time
# --------------------------------------------------------------------
# time
# breathe
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# breathe
# time
# w
# pause
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# pause
# time
# --------------------------------------------------------------------
# time
# w
# pause
# time
# --------------------------------------------------------------------
# time
# non-phonological
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# non-phonological
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# breathe
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# pause
# w
# w
# w
# time
# breathe
# pause
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# breathe
# time
# w
# time
# --------------------------------------------------------------------
# time
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# pause
# time
# w
# time
# --------------------------------------------------------------------
# time
# w
# time
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# time
# w
# w
# pause
# w
# w
# w
# time
# w
# pause
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# non-phonological
# time
# --------------------------------------------------------------------
# time
# breathe
# time
# w
# time
# --------------------------------------------------------------------
# time
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# breathe
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# time
# w
# time
# --------------------------------------------------------------------
# time
# breathe
# time
# --------------------------------------------------------------------
# time
# w
# time
# w
# w
# w
# w
# w
# w
# w
# time
# w
# w
# time
# w
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# time
# --------------------------------------------------------------------
# time
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# non-phonological
# pause
# time
# --------------------------------------------------------------------
# time
# w
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# breathe
# time
# breathe
# time
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# pause
# time
# --------------------------------------------------------------------
# time
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# w
# w
# w
# w
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# w
# w
# w
# time
# --------------------------------------------------------------------
# time
# pause
# time
# --------------------------------------------------------------------

# %%
df
# Out:
#       start      end                                               text
# 0       0.0     1.63
# 0      1.63    2.078                                              läuft
# 0     2.078     2.56
# 0      2.56    3.325                                                  s
# 0      3.23     4.38
# 0      4.38     4.93
# 0      4.93    6.144                        erst mal das grundsätzliche
# 0     6.144    6.642
# 0     6.642     7.45                                   ich lies ihn das
# 0      7.45    7.655
# 0     7.655   11.686   einfach mal vor ähm ham sie scho mal mit der ...
# 0    11.686   11.984                                                 ja
# 0    11.984    12.48
# 0     12.48    17.49   okay aber sonst macht das ihr kollege ne norm...
# 0     17.49   22.158   hm wir sind alle bevollmächtigt das zu tun un...
# 0    22.158   22.642
# 0    22.642   23.925                          die gleiche voraussetzung
# 0    23.925   24.444                                               okay
# 0    24.444    24.72
# 0     24.72    25.07
# 0     25.07   25.272
# 0    25.272   46.857   also das is immer so der standardtext äh was ...
# 0    29.075   29.565                                              hm hm
# 0    44.199   44.714                                              hm hm
# 0    45.614    46.17                                              hm hm
# 0    46.857   47.326                                             stimmt
# 0    47.326   47.618
# 0    47.618   66.962   hierbei gilt maximal drei vermittlungsaufträg...
# 0     62.67    63.15                                              hm hm
# 0    66.962   67.615
# ..      ...      ...                                                ...
# 0   503.476  508.416   bitte nich selber zuschicken lassen sond kurz...
# 0   505.228  505.614                                              hm hm
# 0   506.722  507.073                                              genau
# 0   507.598   509.43     ham wir glaub ich schon mal ei gehabt den f ne
# 0   508.858  509.072
# 0   509.303   515.67   äh ja des war als der letzte personaldisponen...
# 0   512.053  512.494                                              hm hm
# 0   513.037   513.66                                           ja genau
# 0   514.336  514.738                                                 ja
# 0   515.108  515.558                                              genau
# 0    515.67  517.498            so is es ja genau seitdem is das ja wie
# 0   517.194  518.186
# 0   518.186  519.564                                     alles grade ge
# 0   518.568  520.343                                           sehr sch
# 0   519.966  520.343                                                 ja
# 0   520.343  520.648
# 0   520.648  521.272                                               supe
# 0   520.648   520.95                                                 ja
# 0   521.272  522.079                                dann dank ich ihnen
# 0   522.079  522.994                                 ich danke ihn auch
# 0   522.994  523.198
# 0   523.198  524.442                          und wenn sie fragen haben
# 0   524.442  524.696
# 0   524.696  527.174   sie wissen ja wie meine telefonnummer is nich...
# 0   527.174  527.731                                            sehr gu
# 0   527.651  529.782   un sonst hörn wa uns allerspätestens in vier ...
# 0   529.782  530.128
# 0   530.128  530.752                                      ich danke ihn
# 0   530.752  531.496                                      ich danke ihn
# 0   531.496  532.607
#
# [290 rows x 3 columns]

# %%
rootdir = "/home/megha/Desktop/c/DGD-Download_3617D0878D90D0A23A44D6875D3EB642_1553176432773"

tree = ET.parse(rootdir+"/FOLK_E_00190_SE_01_T_01.fln")
root = tree.getroot()
df  = pd.DataFrame(columns = ['A', 'B', 'C'])
for contribution in root.findall("./contribution"):
    #time = contribution.attrib['time']    
    #print(contribution.tag)
    children = contribution.getchildren()    
    time_array = []  
    word = ""
    for child in children:        
        #print(child.tag)
        if(child.tag == "time"):
            #print(child.attrib['time'])
            time_array.append(child.attrib['time'])  
        if(child.tag == "w"):
            #print(child.text)
            word = word+" "+child.text
        df2 = pd.DataFrame([[time_array[0],time_array[-1],word]], columns=list('ABC'))        
    df = df.append(df2)    
#print(df)    
df = df.rename(index=str, columns={"A": "start", "B": "end","C" : "text"})
  

#--------------------------------------------------------------------

time = []
endtime = []
string = []
string_final = []
count = 0
count1 = 10


for i in range(len(df)):
    x = df.get_values()[i]
    #print(x)
    
    if float(x[1]) < count1:
        if count == 0:
            string.append(x[2])
            time.append(float(x[1]))
        else:
            string[-1] = string[-1] + x[2]
            time[-1] = float(x[1])
        count = count + 1
    else:
        count1 = count1 + 10
        count = 0
        endtime.append(time[-1])
        string_final.append(string[-1])
    
print(endtime)
print(string_final)

#create new df 
starttime = []
starttime.append(0.0)
starttime = starttime + endtime[:-1]
string_final =  [x.upper() for x in string_final]
df2 = pd.DataFrame({'col1':starttime, 'col2':endtime, 'col3':string_final})
df2 = df2.drop(df2[df2.col3 ==""].index)
# Out:
# [7.655, 17.49, 25.272, 29.565, 47.618, 47.618, 67.615, 75.598, 89.596, 93.24, 107.65, 118.024, 129.736, 139.924, 144.962, 156.484, 163.454, 176.648, 189.07, 199.358, 201.036, 219.204, 223.858, 233.054, 247.799, 258.274, 268.444, 276.888, 289.622, 298.834, 309.939, 319.782, 329.364, 336.174, 339.82, 339.82, 369.346, 370.253, 389.148, 398.292, 401.386, 412.538, 425.956, 434.814, 449.56, 455.674, 465.76, 479.482, 489.938, 499.808, 509.072, 519.564, 529.782]
# [' läuft s erst mal das grundsätzliche ich lies ihn das', ' ja okay aber sonst macht das ihr kollege ne normalerweise oder grundsätzlich oder machen sie das auch', ' die gleiche voraussetzung okay', ' hm hm', ' hm hm stimmt', ' hm hm stimmt', '', ' hm hm hm hm n o', '', ' ok verstanden ne', ' hm hm', '', '', ' und maximal fünf kenntnisse und fertigkeiten liegt einfach daran dass wir ein bei diesem matching suchlauf ähm', ' nach prioritäten gehn wenn sie zehn stück eintragen bekommen', ' er drei o ähnl also hm hm hm hm', ' hm hm', ' okay hm hm hm hm hm hm hm hm hm hm hm hm o ja', ' ok hm hm', ' hm hm et ceter hm hm hm hm', ' ja', ' hm hm streichen kann als male sondern hm hm das n müssten sie fe sie kenn die stelle sie kenn de auftr hm hm hm hm hm hm', '', ' hm hm hm hm', ' hm hm hm hm im netz seh hm hm das war der erste part', ' des weiteren wird vereinbart dass der arbeitgeber die rückmeldung zu den vermittlungsvorschlägen das heißt stellenbesetzung in der regel wöchentlich ergänzt ähm', ' hm hm', ' hm hm äh hat sich nich vorgest un gelöscht werden sollten sie erst komplett nach drei mon hm hm hm hm okay', ' dafür arbeite ich dafür arbeiten sie und das is so meine erfolgsquote hm hm wir müssen ja auch unsre sollzahlen erreich hm h von daher', ' das is ja auch bisher immer erfolglos wenn wir weiterhin auch so for genau mh dadurch dass sie auch auf meim platz zwei sind als arbeitgeber sehr schön haha', ' zusätzliche vermittlungsvorschläge werden nur auf anforderung nachgebucht also wenn sie n suchlauf haben möchten nehmen sie kontakt zu mir auf am besten über die jobbörse hm hm', ' hm hm maximal drei pro tag eben aus den hm hm s gründen', ' aber da auch wieder die ausnahme wenn sie s ganz dringend haben rufen sie kurz an dann kann ich ihn sagen wie die lage is wenn sie ne vertretung von mir dran ham würde ich sie bitten bei den drei zu bleiben hm hm', ' hm hm hm bei accountbesprechung dürfen sie auch gerne mehr', ' hm hm', ' hm hm', ' hm hm über die job und mir schicken auf welche stelle ich die buchen soll am besten auch über die jobbörse hm hm hm hm okay ähm un dann guck ich ob die passen oder nich passen hm hm', '', ' hm hm hm hm hm hm hm hm hm hm hm hm hm hm hm hm hm hm', ' ja is ja ne tolle sache ja aber ich ähm kann ihn halt aus datenschutzgründen nicht sagen wieso weshalb warum ich denjenigen nich vorschla ka ne hm hm', '', ' hm h', ' hm hm hm hm hm h okay', ' hm hm', ' auch reha und reha es be bewerber zu berücksichtigen also wir ham n spezielles team', ' das nur für rehabilitanten und schwerbehinderte zuständi is und ähm die würden dann direkt mit ihnen hm hm okay', ' hm hm hm hm ok', ' hm hm hm hm ok ja ja ham sie noch fragen erst ma', ' wir ham ja schon erfahrungswerte in de zusammen und äh hm hm da hab ich der ganzen sache im grund gnommen nichts hinzuzufügen', ' ganz außer dass das es bisher immer alles wunderbar funktioniert hat ne ja schön gen wie wie wie sie mir das jetz hier erö ne so is es da freu ich mich ja gen ja', ' bitte nich selber zuschicken lassen sond kurz mich anrufen dann kann ich ihn s direk am telef durchgeben hm hm genau ham wir glaub ich schon mal ei gehabt den f ne', ' hm hm ja genau ja genau so is es ja genau seitdem is das ja wie alles grade ge', ' ja supe ja dann dank ich ihnen ich danke ihn auch und wenn sie fragen haben sie wissen ja wie meine telefonnummer is nich wahr sehr gu un sonst hörn wa uns allerspätestens in vier wochen wieder']

# %%
rootdir = "/home/megha/Desktop/c/DGD-Download_3617D0878D90D0A23A44D6875D3EB642_1553176432773"

tree = ET.parse(rootdir+"/FOLK_E_00190_SE_01_T_02.fln")
root = tree.getroot()
df  = pd.DataFrame(columns = ['A', 'B', 'C'])
for contribution in root.findall("./contribution"):
    #time = contribution.attrib['time']    
    #print(contribution.tag)
    children = contribution.getchildren()    
    time_array = []  
    word = ""
    for child in children:        
        #print(child.tag)
        if(child.tag == "time"):
            #print(child.attrib['time'])
            time_array.append(child.attrib['time'])  
        if(child.tag == "w"):
            #print(child.text)
            word = word+" "+child.text
        df5 = pd.DataFrame([[time_array[0],time_array[-1],word]], columns=list('ABC'))        
    df = df.append(df5)    
#print(df)    
df = df.rename(index=str, columns={"A": "start", "B": "end","C" : "text"})
  

#--------------------------------------------------------------------

time = []
endtime = []
string = []
string_final = []
count = 0
count1 = 10


for i in range(len(df)):
    x = df.get_values()[i]
    #print(x)
    
    if float(x[1]) < count1:
        if count == 0:
            string.append(x[2])
            time.append(float(x[1]))
        else:
            string[-1] = string[-1] + x[2]
            time[-1] = float(x[1])
        count = count + 1
    else:
        count1 = count1 + 10
        count = 0
        endtime.append(time[-1])
        string_final.append(string[-1])
    
print(endtime)
print(string_final)

#create new df 
starttime = []
starttime.append(0.0)
starttime = starttime + endtime[:-1]
string_final =  [x.upper() for x in string_final]
df5 = pd.DataFrame({'col1':starttime, 'col2':endtime, 'col3':string_final})
df5 = df5.drop(df2[df2.col3 ==""].index)
# Out:
# [8.32, 19.685, 28.56, 39.004, 47.608, 55.974, 55.974, 79.348, 88.576, 92.475, 108.826, 115.67, 125.365, 138.14, 147.311, 159.43, 159.43, 177.176, 188.905, 193.748, 207.578, 213.482, 226.648, 239.979, 245.84, 257.226, 266.454, 277.756, 289.908, 297.852, 304.794, 318.75, 329.979, 339.722, 348.434, 358.109, 369.734, 378.282, 387.838, 394.882, 407.646, 419.158, 428.978, 437.582, 449.006, 458.87, 469.149, 479.688, 489.906, 496.324, 509.898, 516.239, 516.239, 535.292, 547.66, 559.656]
ber wir könn ihn leider nich gebrauchen dann müss wa damit leben ne', ' hm hm hm hm', ' hm hm hm hm hm hm ja hm hm', ' bekomm die jetz in der tr si müsste ma dann ma hm hm hm hm hm hm schaun weil da ha ma schon natürlich einige da die roh gemacht ha ne hm hm hm hm hm hm', ' lebensalter also hm h öh da ham wir natürlich auch immer wieder die situation', ' hm hm kollegen da bevorzugen hm hm', ' na ja hm hm ich find ich fin s sehr schade aber is halt so ne also ich kann s halt nich ähm ja beeinflussen wenn der kunde mir das so vorgibt un sacht also bitte', ' ja leider nee so is das geschäft das is ähm ja verständ ja ja so is es ähm ich bin äh', ' mh ich bin guck grade auf m kalender ich bin am zweiten januar wieder hier okay', ' den feiert und äh hm neu ...

# %%
rootdir= "/home/megha/Desktop/c"

# 1) # make new directory and convert the wav file
#---------------------------------------------------------------------------------------------------------------
if True: #False  True
    i= 0
    for Dir in natsort.natsorted(os.listdir(rootdir)):
        if not os.path.exists(rootdir+"/"+Dir+"/temp"): 
            os.makedirs(rootdir+"/"+Dir+"/temp")
        i = i+1
        for file in natsort.natsorted(os.listdir(rootdir+"/"+Dir)):
            if(file.endswith(".WAV")):
                actual_filename = "folk_"+str(i)
                a = os.system('ffmpeg -i "{}" -acodec pcm_s16le -ac 1 -ar 16000 "{}/{}".wav'.format(rootdir+"/"+Dir+"/"+file, rootdir+"/"+Dir+"/temp", actual_filename))# (source,target(half path),name_of_file)
                print(a)
                if(a==256):
                        print("Did not get converted")
            if(file.endswith(".fln")):
                shutil.copyfile(rootdir+"/"+Dir+"/"+file, rootdir+"/"+Dir+"/temp/"+file)
            
#2) extract information from .fln file
#---------------------------------------------------------------------------------------------------------------
if False: #False  True
    for Dir in natsort.natsorted(os.listdir(rootdir)):
        fileName=""
        df  = pd.DataFrame(columns = ['A', 'B', 'C'])
        #print(Dir)
        for file in os.listdir(rootdir+"/"+Dir+"/temp"):            
            if(file.endswith(".wav")):
                fileName = file.split('.')[-2]+"_"
        for file in natsort.natsorted(os.listdir(rootdir+"/"+Dir+"/temp")):
            if(file.endswith(".fln")):                
                if(file.endswith(".fln") and file.split('_')[-1]=="01.fln" ):
                    tree = ET.parse(rootdir+"/"+Dir+"/temp/"+file)
                    root = tree.getroot()
                    for contribution in root.findall("./contribution"):
                        children = contribution.getchildren()
                        time_array = []  
                        word = ""
                        for child in children:
                            if(child.tag == "time"):
                                time_array.append(child.attrib['time'])
                            if(child.tag == "uncertain"):
                                for c in child:
                                    word = word+" "+c.text
                            if(child.tag == "w"):
                                word = word+" "+child.text
                            df_a = pd.DataFrame([[time_array[0],time_array[-1],word]], columns=list('ABC'))
                        df = df.append(df_a,ignore_index = True) 
                if(file.endswith(".fln") and file.split('_')[-1]=="02.fln" ):                    
                    tree = ET.parse(rootdir+"/"+Dir+"/temp/"+file)
                    root = tree.getroot()
                    for contribution in root.findall("./contribution"):
                        children = contribution.getchildren()
                        time_array = []  
                        word = ""
                        for child in children:
                            if(child.tag == "time"):
                                time_array.append(child.attrib['time'])
                            if(child.tag == "uncertain"):
                                for c in child:
                                    word = word+" "+c.text
                            if(child.tag == "w"):
                                word = word+" "+child.text
                            df_b = pd.DataFrame([[time_array[0],time_array[-1],word]], columns=list('ABC'))
                        df = df.append(df_b,ignore_index = True)
                if(file.endswith(".fln") and file.split('_')[-1]=="03.fln" ):
                    tree = ET.parse(rootdir+"/"+Dir+"/temp/"+file)
                    root = tree.getroot()
                    for contribution in root.findall("./contribution"):
                        children = contribution.getchildren()
                        time_array = []  
                        word = ""
                        for child in children:
                            if(child.tag == "time"):
                                time_array.append(child.attrib['time'])
                            if(child.tag == "uncertain"):
                                for c in child:
                                    word = word+" "+c.text
                            if(child.tag == "w"):
                                word = word+" "+child.text
                            df_c = pd.DataFrame([[time_array[0],time_array[-1],word]], columns=list('ABC'))
                        df = df.append(df_c,ignore_index = True)
                df = df.rename(index=str, columns={"A": "start", "B": "end","C" : "text"})
                time = []
                endtime = []
                string = []
                string_final = []
                count = 0
                count1 = 10
                for i in range(len(df)):
                    x = df.get_values()[i]
                    if float(x[1]) < count1:
                        if count == 0:
                            string.append(x[2])
                            time.append(float(x[1]))
                        else:
                            string[-1] = string[-1] + x[2]
                            time[-1] = float(x[1])
                        count = count + 1
                    else:                       
                        string.append(x[2])
                        time.append(float(x[1]))
                        #print(string)
                        #print(time)
                        #print(x)
                        string[-1] = string[-1] + x[2]
                        time[-1] = float(x[1])
                        count1 = count1 + 10
                        count = 0
                        print(time)
                        print('§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§')
                        print(endtime)
                        print('@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@')
                        print(time[-1])
                        endtime.append(time[-1])
                        string_final.append(string[-1])
                #create new df 
                starttime = []
                starttime.append(0.0)
                starttime = starttime + endtime[:-1]
                #print('§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§')
                #print(string_final)
                #print('§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§')
                string_final =  [x.upper() for x in string_final]                
                df2 = pd.DataFrame({'col1':starttime, 'col2':endtime, 'col3':string_final})
                df2 = df2.drop(df2[df2.col3 ==""].index)  
                filename_list = []
                for i in range(0, len(df2)):                    
                    filename_list.extend([fileName+str(i)])    
                df2['col4'] = filename_list
                print(df2.shape)
                #print(df2)
                #----------------------------txt file creation-----------------------------------------------------------------   
                with open(rootdir+"/"+Dir+"/temp/"+"folk.trans.txt", "a") as file:
                    for i in range(0, len(df2)):
                        file.write(df2['col4'].iloc[i]+" "+df2['col3'].iloc[i]+"\n")
                #----------------------------chuncking-----------------------------------------------------------------   
                for file1 in natsort.natsorted(os.listdir(rootdir+"/"+Dir+"/temp/")):
                    #print(file1)  
                    if(file1.endswith(".wav")):
                        myaudio = AudioSegment.from_file(rootdir+"/"+Dir+"/temp/"+file1, "wav")
                        for i in range(0, len(df2)):
                            START = (df2['col1'].iloc[i] * 1000)
                            END = (df2['col2'].iloc[i] * 1000)
                            chunk = myaudio[START:END]                   
                            #chunk_name = file1.split('.')[-2]+"_"+str(i)+".wav" 
                            chunk_name = df2['col4'].iloc[i]+".flac" 
                            #print(chunk_name)
                            if not os.path.exists(rootdir+"/"+Dir+"/temp/"+chunk_name):
                                #print("exporting", chunk_name)
                                chunk.export(rootdir+"/"+Dir+"/temp/"+chunk_name, format="wav")
                                
#--------------------------------------cleaning folder---------------------------------------------
if False: # False True
    for Dir in natsort.natsorted(os.listdir(rootdir)):
        #print(Dir)
        for file in natsort.natsorted(os.listdir(rootdir+"/"+Dir)):
            print(file)
            if(file.endswith(".xml") or file.endswith(".WAV") or file.endswith(".fln") or file.endswith(".html")):
                os.remove(rootdir+"/"+Dir+"/"+file)
        for file in natsort.natsorted(os.listdir(rootdir+"/"+Dir+"/temp")):
            print(file)
            if(file.endswith(".fln") or file.endswith(".wav")):
                os.remove(rootdir+"/"+Dir+"/temp/"+file)
            else:
                shutil.move(rootdir+"/"+Dir+"/temp/"+file, rootdir+"/"+Dir+"/"+file)
        os.rmdir(rootdir+"/"+Dir+"/temp/")
# Out:
# 0

# %%
if True: #False  True
    for Dir in natsort.natsorted(os.listdir(rootdir)):
        fileName=""
        df  = pd.DataFrame(columns = ['A', 'B', 'C'])
        df_a = pd.DataFrame(columns = ['A', 'B', 'C'])
        df_b = pd.DataFrame(columns = ['A', 'B', 'C'])
        df_c = pd.DataFrame(columns = ['A', 'B', 'C'])
        #print(Dir)
        for file in os.listdir(rootdir+"/"+Dir+"/temp"):            
            if(file.endswith(".wav")):
                fileName = file.split('.')[-2]+"_"
        for file in natsort.natsorted(os.listdir(rootdir+"/"+Dir+"/temp")):
            if(file.endswith(".fln")):                
                if(file.endswith(".fln") and file.split('_')[-1]=="01.fln" ):
                    print("----------------------------01-----------------------------")
                    tree = ET.parse(rootdir+"/"+Dir+"/temp/"+file)
                    root = tree.getroot()
                    for contribution in root.findall("./contribution"):
                        children = contribution.getchildren()
                        time_array = []  
                        word = ""
                        for child in children:
                            if(child.tag == "time"):
                                time_array.append(child.attrib['time'])
                            if(child.tag == "uncertain"):
                                for c in child:
                                    word = word+" "+c.text
                            if(child.tag == "w"):
                                word = word+" "+child.text
                            df_a = pd.DataFrame([[time_array[0],time_array[-1],word]], columns=list('ABC'))
                            #print(df_a)
                        df = df.append(df_a,ignore_index = True) 
                if(file.endswith(".fln") and file.split('_')[-1]=="02.fln" ):  
                    print("----------------------------02-----------------------------")
                    tree = ET.parse(rootdir+"/"+Dir+"/temp/"+file)
                    root = tree.getroot()
                    for contribution in root.findall("./contribution"):
                        children = contribution.getchildren()
                        time_array = []  
                        word = ""
                        for child in children:
                            if(child.tag == "time"):
                                time_array.append(child.attrib['time'])
                            if(child.tag == "uncertain"):
                                for c in child:
                                    word = word+" "+c.text
                            if(child.tag == "w"):
                                word = word+" "+child.text
                            df_b = pd.DataFrame([[time_array[0],time_array[-1],word]], columns=list('ABC'))
                            #print(df_b)
                        df = df.append(df_b,ignore_index = True)
                if(file.endswith(".fln") and file.split('_')[-1]=="03.fln" ):  
                    print("----------------------------03-----------------------------")
                    tree = ET.parse(rootdir+"/"+Dir+"/temp/"+file)
                    root = tree.getroot()
                    for contribution in root.findall("./contribution"):
                        children = contribution.getchildren()
                        time_array = []  
                        word = ""
                        for child in children:
                            if(child.tag == "time"):
                                time_array.append(child.attrib['time'])
                            if(child.tag == "uncertain"):
                                for c in child:
                                    word = word+" "+c.text
                            if(child.tag == "w"):
                                word = word+" "+child.text
                            df_c = pd.DataFrame([[time_array[0],time_array[-1],word]], columns=list('ABC'))
                            df_c = df_c[['A','B','C']]
                            #print(df_c)
                            print(df)
                        df = df.append(df_c,ignore_index = True)
                df = df.rename(index=str, columns={"A": "start", "B": "end","C" : "text"})
# Out:
# ----------------------------01-----------------------------
# ----------------------------02-----------------------------
# ----------------------------03-----------------------------
#          start       end                                               text  \
# 0          NaN       NaN                                                NaN
# 1          NaN       NaN                                                NaN
# 2          NaN       NaN                                                NaN
# 3          NaN       NaN                                                NaN
# 4          NaN       NaN                                                NaN
# 5          NaN       NaN                                                NaN
# 6          NaN       NaN                                                NaN
# 7          NaN       NaN                                                NaN
# 8          NaN       NaN                                                NaN
# 9          NaN       NaN                                                NaN
# 10         NaN       NaN                                                NaN
# 11         NaN       NaN                                                NaN
# 12         NaN       NaN                                                NaN
# 13         NaN       NaN                                                NaN
# 14         NaN       NaN                                                NaN
# 15         NaN       NaN                                                NaN
# 16         NaN       NaN                                                NaN
# 17         NaN       NaN                                                NaN
# 18         NaN       NaN                                                NaN
# 19         NaN       NaN                                                NaN
# 20         NaN       NaN                                                NaN
# 21         NaN       NaN                                                NaN
# 22         NaN       NaN                                                NaN
# 23         NaN       NaN                                                NaN
# 24         NaN       NaN                                                NaN
# 25         NaN       NaN                                                NaN
# 26         NaN       NaN                                                NaN
# 27         NaN       NaN                                                NaN
# 28         NaN       NaN                                                NaN
# 29         NaN       NaN                                                NaN
# ...        ...       ...                                                ...
# 2652  2969.556  2970.616
# 2653  2970.616  2971.231
# 2654  2971.231  2972.041
# 2655  2972.041  2975.261   wo ick weeß jar ni ole hat det gloob ick ooch...
# 2656  2975.066  2975.996                              ick weeß det jar nich
# 2657  2975.996  2976.276
# 2658  2976.276  2977.931          irgendwer hat et noch wer hat mir des jes
# 2659  2977.531  2977.666                                                 na
# 2660  2977.931  2978.816                                     fredi hat noch
# 2661  2978.816  2980.331
# 2662  2980.331  2981.726                      fredi hat ooch n film jedreht
# 2663  2981.726  2982.036
# 2664  2982.036  2982.211                                                 ja
# 2665  2982.211  2982.481
# 2666  2982.481  2982.776                                              hm hm
# 2667  2982.776  2984.031
# 2668  2984.031  2984.841                           bin ick echt ma jespannt
# 2669  2984.841  2987.466
# 2670  2987.466  2988.761
# 2671  2988.761  2992.621
# 2672  2992.621  2998.941   a t ging mir ooch uff die nerven da mit dem m...
# 2673  2995.391  2995.711                                             nee de
# 2674  2995.936  2996.796                                     da ka e nich m
# 2675  2998.841  3003.461          ja ja ja det kannst e nich die janze zeit
# 2676  3002.931  3004.161                    und julian hat det nich kapiert
# 2677  3004.161  3004.496
# 2678  3004.496  3005.196                                                 ja
# 2679  3004.496  3005.011                                             ++++++
# 2680  3005.196  3006.856                   ick hab ja julian immer so wo er
# 2681  3006.526  3006.856                                              jenau
#
#          end   start                                               text
# 0      7.179   6.644                                               pein
# 1      7.179   6.814
# 2     14.199   7.179
# 3     15.764  14.199              wollen wa ma wasser aufmachen soll ma
# 4     18.979  15.764
# 5     20.169  18.979
# 6     23.114  20.169
# 7     23.474  23.114                                                 so
# 8     28.074  23.474
# 9     28.609  28.074
# 10    35.444  28.609
# 11    36.894  35.444
# 12    38.404  36.894
# 13    39.764  38.404          und beim husten bisschen weiter zurück wa
# 14    40.044  39.764
# 15    43.249  40.044   ja genau und nicht gegen den tisch ditschen i...
# 16    43.249  42.679
# 17    43.824  43.249
# 18    44.139  43.824                                           warte ma
# 19    46.894  44.139   die schaumstoffmatte na ja stell s nich so we...
# 20    47.254  46.894
# 21    47.614  47.254                                                jut
# 22    48.259  47.614
# 23    50.559  48.259   aber nich so of also wenn du ma jegenditschst...
# 24    50.899  50.559
# 25    52.974  50.899      dass ick halt nich dass ick halt nich wie ole
# 26    53.359  52.974                                                  g
# 27    53.679  53.034                                     es genau mache
# 28    54.079  53.679                                              genau
# 29    54.279  54.079
# ...      ...     ...                                                ...
# 2652     NaN     NaN                                                NaN
# 2653     NaN     NaN                                                NaN
# 2654     NaN     NaN                                                NaN
# 2655     NaN     NaN                                                NaN
# 2656     NaN     NaN                                                NaN
# 2657     NaN     NaN                                                NaN
# 2658     NaN     NaN                                                NaN
# 2659     NaN     NaN                                                NaN
# 2660     NaN     NaN                                                NaN
# 2661     NaN     NaN                                                NaN
# 2662     NaN     NaN                                                NaN
# 2663     NaN     NaN                                                NaN
# 2664     NaN     NaN                                                NaN
# 2665     NaN     NaN                                                NaN
# 2666     NaN     NaN                                                NaN
# 2667     NaN     NaN                                                NaN
# 2668     NaN     NaN                                                NaN
# 2669     NaN     NaN                                                NaN
# 2670     NaN     NaN                                                NaN
# 2671     NaN     NaN                                                NaN
# 2672     NaN     NaN                                                NaN
# 2673     NaN     NaN                                                NaN
# 2674     NaN     NaN                                                NaN
# 2675     NaN     NaN                                                NaN
# 2676     NaN     NaN                                                NaN
# 2677     NaN     NaN                                                NaN
# 2678     NaN     NaN                                                NaN
# 2679     NaN     NaN                                                NaN
# 2680     NaN     NaN                                                NaN
# 2681     NaN     NaN                                                NaN
#
# [2682 rows x 6 columns]
#          start       end                                               text  \
# 0          NaN       NaN                                                NaN
# 1          NaN       NaN                                                NaN
# 2          NaN       NaN                                                NaN
# 3          NaN       NaN                                                NaN
# 4          NaN       NaN                                                NaN
# 5          NaN       NaN                                                NaN
# 6          NaN       NaN                                                NaN
# 7          NaN       NaN                                                NaN
# 8          NaN       NaN                                                NaN
# 9          NaN       NaN                                                NaN
# 10         NaN       NaN                                                NaN
# 11         NaN       NaN                                                NaN
# 12         NaN       NaN                                                NaN
# 13         NaN       NaN                                                NaN
# 14         NaN       NaN                                                NaN
# 15         NaN       NaN                                                NaN
# 10         NaN       NaN                                                NaN
# 11         NaN       NaN                                                NaN
# 12         NaN       NaN                                                NaN
# 13         NaN       NaN                                                NaN
# 14         NaN       NaN                                                NaN
# 15         NaN       NaN                                                NaN
# 16         NaN       NaN                                                NaN
# 17         NaN       NaN                                                NaN
# 18         NaN       NaN                                                NaN
# 19         NaN       NaN                                                NaN
# 20         NaN       NaN                                                NaN
# 21         NaN       NaN                                                NaN
# 22         NaN       NaN                                                NaN
# 23         NaN       NaN                                                NaN
# 24         NaN       NaN                                                NaN
# 25         NaN       NaN                                                NaN
# 26         NaN       NaN                                                NaN
# 27         NaN       NaN                                                NaN
# 28         NaN       NaN                                                NaN
# 29         NaN       NaN                                                NaN
# ...        ...       ...                                                ...
# 2652  2969.556  2970.616
# 2653  2970.616  2971.231
# 2654  2971.231  2972.041
# 2655  2972.041  2975.261   wo ick weeß jar ni ole hat det gloob ick ooch...
# 2656  2975.066  2975.996                              ick weeß det jar nich
# 2657  2975.996  2976.276
# 2658  2976.276  2977.931          irgendwer hat et noch wer hat mir des jes
# 2659  2977.531  2977.666                                                 na
# 2660  2977.931  2978.816                                     fredi hat noch
# 2661  2978.816  2980.331
# 2662  2980.331  2981.726                      fredi hat ooch n film jedreht
# 2663  2981.726  2982.036
# 2664  2982.036  2982.211                                                 ja
# 2665  2982.211  2982.481
# 2666  2982.481  2982.776                                              hm hm
# 2667  2982.776  2984.031
# 2668  2984.031  2984.841                           bin ick echt ma jespannt
# 2669  2984.841  2987.466
# 2670  2987.466  2988.761
# 2671  2988.761  2992.621
# 2672  2992.621  2998.941   a t ging mir ooch uff die nerven da mit dem m...
# 2673  2995.391  2995.711                                             nee de
# 2674  2995.936  2996.796                                     da ka e nich m
# 2675  2998.841  3003.461          ja ja ja det kannst e nich die janze zeit
# 2676  3002.931  3004.161                    und julian hat det nich kapiert
# 2677  3004.161  3004.496
# 2678  3004.496  3005.196                                                 ja
# 2679  3004.496  3005.011                                             ++++++
# 2680  3005.196  3006.856                   ick hab ja julian immer so wo er
# 2681  3006.526  3006.856                                              jenau
#
#          end   start                                               text
# 0      7.179   6.644                                               pein
# 1      7.179   6.814
# 2     14.199   7.179
# 3     15.764  14.199              wollen wa ma wasser aufmachen soll ma
# 4     18.979  15.764
# 5     20.169  18.979
# 6     23.114  20.169
# 7     23.474  23.114                                                 so
# 8     28.074  23.474
# 9     28.609  28.074
# 10    35.444  28.609
# 11    36.894  35.444
# 12    38.404  36.894
# 13    39.764  38.404          und beim husten bisschen weiter zurück wa
# 14    40.044  39.764
# 15    43.249  40.044   ja genau und nicht gegen den tisch ditschen i...
# 16    43.249  42.679
# 17    43.824  43.249
# 18    44.139  43.824                                           warte ma
# 19    46.894  44.139   die schaumstoffmatte na ja stell s nich so we...
# 20    47.254  46.894
# 21    47.614  47.254                                                jut
# 22    48.259  47.614
# 23    50.559  48.259   aber nich so of also wenn du ma jegenditschst...
# 24    50.899  50.559
# 25    52.974  50.899      dass ick halt nich dass ick halt nich wie ole
# 26    53.359  52.974                                                  g
# 27    53.679  53.034                                     es genau mache
# 28    54.079  53.679                                              genau
# 29    54.279  54.079
# ...      ...     ...                                                ...
# 2652     NaN     NaN                                                NaN
# 2653     NaN     NaN                                                NaN
# 2654     NaN     NaN                                                NaN
# 2655     NaN     NaN                                                NaN
# 2656     NaN     NaN                                                NaN
# 2657     NaN     NaN                                                NaN
# 2658     NaN     NaN                                                NaN
# 2659     NaN     NaN                                                NaN
# 2660     NaN     NaN                                                NaN
# 2661     NaN     NaN                                                NaN
# 2662     NaN     NaN                                                NaN
# 2663     NaN     NaN                                                NaN
# 2664     NaN     NaN                                                NaN
# 2665     NaN     NaN                                                NaN
# 2666     NaN     NaN                                                NaN
# 2667     NaN     NaN                                                NaN
# 2668     NaN     NaN                                                NaN
# 2669     NaN     NaN                                                NaN
# 2670     NaN     NaN                                                NaN
# 2671     NaN     NaN                                                NaN
# 2672     NaN     NaN                                                NaN
# 2673     NaN     NaN                                                NaN
# 2674     NaN     NaN                                                NaN
# 2675     NaN     NaN                                                NaN
# 2676     NaN     NaN                                                NaN
# 2677     NaN     NaN                                                NaN
# 2678     NaN     NaN                                                NaN
# 2679     NaN     NaN                                                NaN
# 2680     NaN     NaN                                                NaN
# 2681     NaN     NaN                                                NaN
#
# [2682 rows x 6 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-8964a7bc1cf3> in <module>
#      67                             #print(df_c)
#      68                             print(df)
# ---> 69                         df = df.append(df_c,ignore_index = True)
#      70                 df = df.rename(index=str, columns={"A": "start", "B": "end","C" : "text"})
#      71
#
# ~/py_36_env/lib/python3.6/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    6699         return concat(to_concat, ignore_index=ignore_index,
#    6700                       verify_integrity=verify_integrity,
# -> 6701                       sort=sort)
#    6702
#    6703     def join(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# ~/py_36_env/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     227                        verify_integrity=verify_integrity,
#     228                        copy=copy, sort=sort)
# --> 229     return op.get_result()
#     230
#     231
#
# ~/py_36_env/lib/python3.6/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     424             new_data = concatenate_block_managers(
#     425                 mgrs_indexers, self.new_axes, concat_axis=self.axis,
# --> 426                 copy=self.copy)
#     427             if not self.copy:
#     428                 new_data._consolidate_inplace()
#
# ~/py_36_env/lib/python3.6/site-packages/pandas/core/internals/managers.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    2044     blocks = []
#    2045
# -> 2046     for placement, join_units in concat_plan:
#    2047
#    2048         if len(join_units) == 1 and not join_units[0].indexers:
#
# ~/py_36_env/lib/python3.6/site-packages/pandas/core/internals/concat.py in combine_concat_plans(plans, concat_axis)
#     455         while num_ended[0] != len(next_items):
#     456             if num_ended[0] > 0:
# --> 457                 raise ValueError("Plan shapes are not aligned")
#     458
#     459             placements, units = zip(*next_items)
#
# ValueError: Plan shapes are not aligned

# %%
if True: #False  True
    for Dir in natsort.natsorted(os.listdir(rootdir)):
        fileName=""
        df  = pd.DataFrame(columns = ['A', 'B', 'C'])
        #print(Dir)
        for file in os.listdir(rootdir+"/"+Dir+"/temp"):            
            if(file.endswith(".wav")):
                fileName = file.split('.')[-2]+"_"
        for file in natsort.natsorted(os.listdir(rootdir+"/"+Dir+"/temp")):
            if(file.endswith(".fln")):                
                if(file.endswith(".fln") and file.split('_')[-1]=="02.fln" ):
                    print("----------------------------03-----------------------------")
                    tree = ET.parse(rootdir+"/"+Dir+"/temp/"+file)
                    root = tree.getroot()
                    for contribution in root.findall("./contribution"):
                        children = contribution.getchildren()
                        time_array = []  
                        word = ""
                        for child in children:
                            if(child.tag == "time"):
                                time_array.append(child.attrib['time'])
                            if(child.tag == "uncertain"):
                                for c in child:
                                    word = word+" "+c.text
                            if(child.tag == "w"):
                                word = word+" "+child.text
                            df_a = pd.DataFrame([[time_array[0],time_array[-1],word]], columns=list('ABC'))
                            #print(df_a)
                        df = df.append(df_a,ignore_index = True)
# Out:
# ----------------------------03-----------------------------

# %%
df
# Out:
#              A         B                                                  C
# 0     1398.963  1399.308                                              hm hm
# 1     1399.308  1405.128
# 2     1405.128  1406.168                                  ja man is nich so
# 3     1406.168  1406.768
# 4     1406.768  1408.293                          jebunden an irgend n chef
# 5     1408.293  1408.703
# 6     1408.703  1408.993                                                 ja
# 7     1408.993  1409.868
# 8     1409.868  1413.447       wo denn der chef sagt wo et langgeht sondern
# 9     1413.447  1418.127
# 10    1418.127  1418.362
# 11    1418.362  1419.312                                              hm hm
# 12    1419.027  1419.312                                              hm hm
# 13    1419.312  1419.627
# 14    1419.627  1419.957                                              hm hm
# 15    1419.957  1420.342
# 16    1420.342  1421.002
# 17    1421.002  1423.307                                                 ja
# 18    1423.307  1428.717
# 19    1428.717  1430.222           ick hab mi so verliebt in dieset haus wa
# 20    1430.222  1430.617
# 21    1430.617  1431.862                    w wirklich von vorne bis hinten
# 22    1431.862  1433.942
# 23    1433.942  1437.542   sieht man det wenn wenn man f die straße a la...
# 24    1437.542  1439.312
# 25    1439.312  1439.502                                                nee
# 26    1439.502  1439.697                                                nee
# 27    1439.697  1440.137
# 28    1440.137  1441.937        nur an wenn de an der straße b vorbeifährst
# 29    1441.937  1442.562
# ...        ...       ...                                                ...
# 1335  2969.556  2970.616
# 1336  2970.616  2971.231
# 1337  2971.231  2972.041
# 1338  2972.041  2975.261   wo ick weeß jar ni ole hat det gloob ick ooch...
# 1339  2975.066  2975.996                              ick weeß det jar nich
# 1340  2975.996  2976.276
# 1341  2976.276  2977.931          irgendwer hat et noch wer hat mir des jes
# 1342  2977.531  2977.666                                                 na
# 1343  2977.931  2978.816                                     fredi hat noch
# 1344  2978.816  2980.331
# 1345  2980.331  2981.726                      fredi hat ooch n film jedreht
# 1346  2981.726  2982.036
# 1347  2982.036  2982.211                                                 ja
# 1348  2982.211  2982.481
# 1349  2982.481  2982.776                                              hm hm
# 1350  2982.776  2984.031
# 1351  2984.031  2984.841                           bin ick echt ma jespannt
# 1352  2984.841  2987.466
# 1353  2987.466  2988.761
# 1354  2988.761  2992.621
# 1355  2992.621  2998.941   a t ging mir ooch uff die nerven da mit dem m...
# 1356  2995.391  2995.711                                             nee de
# 1357  2995.936  2996.796                                     da ka e nich m
# 1358  2998.841  3003.461          ja ja ja det kannst e nich die janze zeit
# 1359  3002.931  3004.161                    und julian hat det nich kapiert
# 1360  3004.161  3004.496
# 1361  3004.496  3005.196                                                 ja
# 1362  3004.496  3005.011                                             ++++++
# 1363  3005.196  3006.856                   ick hab ja julian immer so wo er
# 1364  3006.526  3006.856                                              jenau
#
# [1365 rows x 3 columns]

# %%
if False: #False  True
    for Dir in natsort.natsorted(os.listdir(rootdir)):
        fileName=""
        df  = pd.DataFrame(columns = ['A', 'B', 'C'])
        #print(Dir)
        for file in os.listdir(rootdir+"/"+Dir+"/temp"):            
            if(file.endswith(".wav")):
                fileName = file.split('.')[-2]+"_"
        for file in natsort.natsorted(os.listdir(rootdir+"/"+Dir+"/temp")):
            if(file.endswith(".fln")):                
                if(file.endswith(".fln") and file.split('_')[-1]=="01.fln" ):
                    tree = ET.parse(rootdir+"/"+Dir+"/temp/"+file)
                    root = tree.getroot()
                    for contribution in root.findall("./contribution"):
                        children = contribution.getchildren()
                        time_array = []  
                        word = ""
                        for child in children:
                            if(child.tag == "time"):
                                time_array.append(child.attrib['time'])
                            if(child.tag == "uncertain"):
                                for c in child:
                                    word = word+" "+c.text
                            if(child.tag == "w"):
                                word = word+" "+child.text
                            df_a = pd.DataFrame([[time_array[0],time_array[-1],word]], columns=list('ABC'))
                        df = df.append(df_a,ignore_index = True) 
                if(file.endswith(".fln") and file.split('_')[-1]=="02.fln" ):                    
                    tree = ET.parse(rootdir+"/"+Dir+"/temp/"+file)
                    root = tree.getroot()
                    for contribution in root.findall("./contribution"):
                        children = contribution.getchildren()
                        time_array = []  
                        word = ""
                        for child in children:
                            if(child.tag == "time"):
                                time_array.append(child.attrib['time'])
                            if(child.tag == "uncertain"):
                                for c in child:
                                    word = word+" "+c.text
                            if(child.tag == "w"):
                                word = word+" "+child.text
                            df_b = pd.DataFrame([[time_array[0],time_array[-1],word]], columns=list('ABC'))
                        df = df.append(df_b,ignore_index = True)
                if(file.endswith(".fln") and file.split('_')[-1]=="03.fln" ):
                    tree = ET.parse(rootdir+"/"+Dir+"/temp/"+file)
                    root = tree.getroot()
                    for contribution in root.findall("./contribution"):
                        children = contribution.getchildren()
                        time_array = []  
                        word = ""
                        for child in children:
                            if(child.tag == "time"):
                                time_array.append(child.attrib['time'])
                            if(child.tag == "uncertain"):
                                for c in child:
                                    word = word+" "+c.text
                            if(child.tag == "w"):
                                word = word+" "+child.text
                            df_c = pd.DataFrame([[time_array[0],time_array[-1],word]], columns=list('ABC'))
                        df = df.append(df_c,ignore_index = True)
                df = df.rename(index=str, columns={"A": "start", "B": "end","C" : "text"})
                time = []
                endtime = []
                string = []
                string_final = []
                count = 0
                count1 = 10
                for i in range(len(df)):
                    x = df.get_values()[i]
                    if float(x[1]) < count1:
                        if count == 0:
                            string.append(x[2])
                            time.append(float(x[1]))
                        else:
                            string[-1] = string[-1] + x[2]
                            time[-1] = float(x[1])
                        count = count + 1
                    else:                       
                        string.append(x[2])
                        time.append(float(x[1]))
                        #print(string)
                        #print(time)
                        #print(x)
                        string[-1] = string[-1] + x[2]
                        time[-1] = float(x[1])
                        count1 = count1 + 10
                        count = 0
                        print(time)
                        print('§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§')
                        print(endtime)
                        print('@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@')
                        print(time[-1])
                        endtime.append(time[-1])
                        string_final.append(string[-1])
                #create new df 
                starttime = []
                starttime.append(0.0)
                starttime = starttime + endtime[:-1]
                #print('§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§')
                #print(string_final)
                #print('§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§')
                string_final =  [x.upper() for x in string_final]                
                df2 = pd.DataFrame({'col1':starttime, 'col2':endtime, 'col3':string_final})
                df2 = df2.drop(df2[df2.col3 ==""].index)  
                filename_list = []
                for i in range(0, len(df2)):                    
                    filename_list.extend([fileName+str(i)])    
                df2['col4'] = filename_list
                print(df2.shape)
                #print(df2)
                #----------------------------txt file creation-----------------------------------------------------------------   
                with open(rootdir+"/"+Dir+"/temp/"+"folk.trans.txt", "a") as file:
                    for i in range(0, len(df2)):
                        file.write(df2['col4'].iloc[i]+" "+df2['col3'].iloc[i]+"\n")
                #----------------------------chuncking-----------------------------------------------------------------   
                for file1 in natsort.natsorted(os.listdir(rootdir+"/"+Dir+"/temp/")):
                    #print(file1)  
                    if(file1.endswith(".wav")):
                        myaudio = AudioSegment.from_file(rootdir+"/"+Dir+"/temp/"+file1, "wav")
                        for i in range(0, len(df2)):
                            START = (df2['col1'].iloc[i] * 1000)
                            END = (df2['col2'].iloc[i] * 1000)
                            chunk = myaudio[START:END]                   
                            #chunk_name = file1.split('.')[-2]+"_"+str(i)+".wav" 
                            chunk_name = df2['col4'].iloc[i]+".flac" 
                            #print(chunk_name)
                            if not os.path.exists(rootdir+"/"+Dir+"/temp/"+chunk_name):
                                #print("exporting", chunk_name)
                                chunk.export(rootdir+"/"+Dir+"/temp/"+chunk_name, format="wav")
# Out:
# FOLK_E_00002_SE_01_T_01.fln
# folk_1.wav
# ----------------------------------------
# FOLK_E_00012_SE_01_T_01.fln
# FOLK_E_00012_SE_01_T_02.fln
# folk_2.wav
# ----------------------------------------
# FOLK_E_00039_SE_01_T_01.fln
# FOLK_E_00039_SE_01_T_02.fln
# FOLK_E_00039_SE_01_T_03.fln
# folk_3.wav
# ----------------------------------------

# %%
fileName="folk_2.wav"
fileName=fileName.split('.')[-2]+"_"

# %%
i = 1
fileName_List = []
fileName_List.append()
# Out:
# 'folk_2_'
