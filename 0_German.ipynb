# %%
import webvtt
from os import listdir
from os.path import isfile, join
import pandas as pd
from pydub import AudioSegment
import os
import shutil
import natsort

# %%
rootdir="/home/megha/Desktop/a"
backup = "/home/megha/Desktop/c" # place holder to move all teh vtt file and teh converted wav files after spliting


#1)
"""
converting all audio to wav file with the following specification. 
    -WAVE files with 16-bit
    -16 kHz
    -mono 
"""
if True: #False  True
    for Dir in natsort.natsorted(os.listdir(rootdir)):
        print(Dir)
        #for subdir in natsort.natsorted(os.listdir(rootdir+"/"+Dir)):        
        length = len(os.listdir(rootdir+"/"+Dir))
        if(length > 2):
            print("file already converted")
        else:
            for file in os.listdir(rootdir+"/"+Dir): 
                if(file.endswith(".wav")):
                    actual_filename = file[:-4]+"_C"
                    a = os.system('ffmpeg -i "{}" -acodec pcm_s16le -ac 1 -ar 16000 "{}/{}".wav'.format(rootdir+"/"+Dir+"/"+file, rootdir+"/"+Dir+"/", actual_filename))# (source,target(half path),name_of_file)
                    #converting diretly to flac did not work. so changing the format in next step
                    print(a)
                    if(a==256):
                        print("Did not get converted")

#------------------------------------------------deleting original file---------------------------------------------------------

if True: #False  True
    for Dir in natsort.natsorted(os.listdir(rootdir)):
            length = len(os.listdir(rootdir+"/"+Dir))
            if(length > 2):
                for file in os.listdir(rootdir+"/"+Dir):
                    if(file.endswith(".wav") and file.split('_')[-1]!="C.wav"):
                        os.remove(rootdir+"/"+Dir+"/"+file)                        
            if(length == 2):
                print(" is being removed")
                #move complete folder the the backup folder
                shutil.move(rootdir+"/"+Dir, backup) # (source,target)

                # 2)
"""
creating chunks and saving in the same folder
"""
if True: #True  False
    for Dir in os.listdir(rootdir):
        df  = pd.DataFrame(columns = ['A', 'B', 'C'])
        for file in os.listdir(rootdir+"/"+Dir):
            if(file.endswith(".vtt")):                
                for caption in webvtt.read(rootdir+"/"+Dir+"/"+file):
                    df2 = pd.DataFrame([[caption.start,caption.end,caption.text]], columns=list('ABC'))
                    df = df.append(df2)
                df = df.rename(index=str, columns={"A": "start", "B": "end","C" : "text"})
        for file in os.listdir(rootdir+"/"+Dir):
            if(file.endswith(".wav") and file.split('_')[-1]=="C.wav"):                
                myaudio = AudioSegment.from_file(rootdir+"/"+Dir+"/"+file, "wav")
                for i in range(0, len(df)):
                    start_time = df['start'].iloc[i]
                    end_time = df['end'].iloc[i]
                    # -----------------------------START-TIME-----------------------------------
                    s_hours, s_minutes, s_seconds = (["0", "0"] + start_time.split(":"))[-3:]
                    s_hours = int(s_hours)
                    s_minutes = int(s_minutes)
                    s_seconds = float(s_seconds)
                    s_millisecond = int(3600000 * s_hours + 60000 * s_minutes + 1000 * s_seconds)
                    START = s_millisecond
                    #-------------------------------END-TIME---------------------------------------
                    e_hours, e_minutes, e_seconds = (["0", "0"] + end_time.split(":"))[-3:]
                    e_hours = int(e_hours)
                    e_minutes = int(e_minutes)
                    e_seconds = float(e_seconds)
                    e_miliseconds = int(3600000 * e_hours + 60000 * e_minutes + 1000 * e_seconds)
                    END = e_miliseconds
                    #--------------------------------------------------------------------------
                    chunk = myaudio[START:END]
                    chunk_name = file.split('.')[-2]+"_"+str(i)+".flac"
                    if not os.path.exists(rootdir+"/"+Dir+"/"+chunk_name):
                        print("exporting", chunk_name)
                        chunk.export(rootdir+"/"+Dir+"/"+chunk_name, format="flac")
                if not os.path.exists(backup+"/"+file):
                    shutil.move(rootdir+"/"+Dir+"/"+file, backup) # (source,target)
                    print("Backing up")
                else:
                    os.remove(rootdir+"/"+Dir+"/"+file)
                    print("File already exist. So just removing")
    #----------------------------------------------txt-----------------------------------------------------------------            
        txt_name = ""        
        for file in natsort.natsorted(os.listdir(rootdir+"/"+Dir)):
            if(file.endswith(".vtt")):
                txt_name = file.split(".")[-2]
        with open(rootdir+"/"+Dir+"/"+txt_name+"_C.trans.txt", "w") as txt_file:
            i=0
            for file in natsort.natsorted(os.listdir(rootdir+"/"+Dir)):                
                if(file.endswith(".flac")):
                    wav_file_name = file.split(".")[-2]
                    #print(df['text'].iloc[i])
                    txt_file.write(wav_file_name+" "+df['text'].iloc[i].upper()+"\n")
                    i = i+1
        for file in natsort.natsorted(os.listdir(rootdir+"/"+Dir)):
            if(file.endswith(".vtt")):
                if not os.path.exists(backup+"/"+file):
                    shutil.move(rootdir+"/"+Dir+"/"+file, backup) # (source,target)
                else:
                    os.remove(rootdir+"/"+Dir+"/"+file)
                    print("File already exist. So just removing")
# Out:
# SUB-19
# 0
# SUB-31
# 0
# SUB-37
# 0
# SUB-43
# 0
# SUB-49
# 0
# SUB-55
# 0
# SUB-61
# 0
# SUB-67
# 0
# exporting 0095_DEU_C_0.flac
# exporting 0095_DEU_C_1.flac
# exporting 0095_DEU_C_2.flac
# exporting 0095_DEU_C_3.flac
# exporting 0095_DEU_C_4.flac
# exporting 0095_DEU_C_5.flac
# exporting 0095_DEU_C_6.flac
# exporting 0095_DEU_C_7.flac
# exporting 0095_DEU_C_8.flac
# exporting 0095_DEU_C_9.flac
# exporting 0095_DEU_C_10.flac
# exporting 0095_DEU_C_11.flac
# exporting 0095_DEU_C_12.flac
# exporting 0095_DEU_C_13.flac
# exporting 0095_DEU_C_14.flac
# exporting 0095_DEU_C_15.flac
# File already exist. So just removing
# File already exist. So just removing
# exporting 0093_DEU_C_0.flac
# exporting 0093_DEU_C_1.flac
# exporting 0093_DEU_C_2.flac
# exporting 0093_DEU_C_3.flac
# exporting 0093_DEU_C_4.flac
# exporting 0093_DEU_C_5.flac
# exporting 0093_DEU_C_6.flac
# exporting 0093_DEU_C_7.flac
# exporting 0093_DEU_C_8.flac
# exporting 0093_DEU_C_9.flac
# exporting 0093_DEU_C_10.flac
# exporting 0093_DEU_C_11.flac
# exporting 0093_DEU_C_12.flac
# exporting 0093_DEU_C_13.flac
# exporting 0093_DEU_C_14.flac
# exporting 0093_DEU_C_15.flac
# exporting 0093_DEU_C_16.flac
# exporting 0093_DEU_C_17.flac
# exporting 0093_DEU_C_18.flac
# exporting 0093_DEU_C_19.flac
# exporting 0093_DEU_C_20.flac
# exporting 0093_DEU_C_21.flac
# exporting 0093_DEU_C_22.flac
# exporting 0093_DEU_C_23.flac
# exporting 0093_DEU_C_24.flac
# exporting 0093_DEU_C_25.flac
# exporting 0093_DEU_C_26.flac
# exporting 0093_DEU_C_27.flac
# exporting 0093_DEU_C_28.flac
# File already exist. So just removing
# File already exist. So just removing
# exporting 0071_DEU_C_0.flac
# exporting 0071_DEU_C_1.flac
# exporting 0071_DEU_C_2.flac
# exporting 0071_DEU_C_3.flac
# exporting 0071_DEU_C_4.flac
# exporting 0071_DEU_C_5.flac
# exporting 0071_DEU_C_6.flac
# exporting 0071_DEU_C_7.flac
# exporting 0071_DEU_C_8.flac
# exporting 0071_DEU_C_9.flac
# exporting 0071_DEU_C_10.flac
# exporting 0071_DEU_C_11.flac
# exporting 0071_DEU_C_12.flac
# exporting 0071_DEU_C_13.flac
# exporting 0071_DEU_C_14.flac
# exporting 0071_DEU_C_15.flac
# exporting 0071_DEU_C_16.flac
# exporting 0071_DEU_C_17.flac
# exporting 0071_DEU_C_18.flac
# exporting 0071_DEU_C_19.flac
# exporting 0071_DEU_C_20.flac
# exporting 0071_DEU_C_21.flac
# exporting 0071_DEU_C_22.flac
# exporting 0071_DEU_C_23.flac
# File already exist. So just removing
# File already exist. So just removing
# exporting 0041_DEU_C_0.flac
# exporting 0041_DEU_C_1.flac
# exporting 0041_DEU_C_2.flac
# exporting 0041_DEU_C_3.flac
# exporting 0041_DEU_C_4.flac
# exporting 0041_DEU_C_5.flac
# exporting 0041_DEU_C_6.flac
# exporting 0041_DEU_C_7.flac
# exporting 0041_DEU_C_8.flac
# exporting 0041_DEU_C_9.flac
# exporting 0041_DEU_C_10.flac
# exporting 0041_DEU_C_11.flac
# exporting 0041_DEU_C_12.flac
# exporting 0041_DEU_C_13.flac
# exporting 0041_DEU_C_14.flac
# exporting 0041_DEU_C_15.flac
# exporting 0041_DEU_C_16.flac
# exporting 0041_DEU_C_17.flac
# exporting 0041_DEU_C_18.flac
# exporting 0041_DEU_C_19.flac
# exporting 0041_DEU_C_20.flac
# exporting 0041_DEU_C_21.flac
# File already exist. So just removing
# File already exist. So just removing
# exporting 0039_DEU_C_0.flac
# exporting 0039_DEU_C_1.flac
# exporting 0039_DEU_C_2.flac
# exporting 0039_DEU_C_3.flac
# exporting 0039_DEU_C_4.flac
# exporting 0039_DEU_C_5.flac
# exporting 0039_DEU_C_6.flac
# exporting 0039_DEU_C_7.flac
# exporting 0039_DEU_C_8.flac
# exporting 0039_DEU_C_9.flac
# exporting 0039_DEU_C_10.flac
# exporting 0039_DEU_C_11.flac
# exporting 0039_DEU_C_12.flac
# exporting 0039_DEU_C_13.flac
# exporting 0039_DEU_C_14.flac
# exporting 0039_DEU_C_15.flac
# exporting 0039_DEU_C_16.flac
# File already exist. So just removing
# File already exist. So just removing
# exporting 0124_DEU_C_0.flac
# exporting 0124_DEU_C_1.flac
# exporting 0124_DEU_C_2.flac
# exporting 0124_DEU_C_3.flac
# exporting 0124_DEU_C_4.flac
# exporting 0124_DEU_C_5.flac
# exporting 0124_DEU_C_6.flac
# exporting 0124_DEU_C_7.flac
# exporting 0124_DEU_C_8.flac
# exporting 0124_DEU_C_9.flac
# exporting 0124_DEU_C_10.flac
# exporting 0124_DEU_C_11.flac
# exporting 0124_DEU_C_12.flac
# exporting 0124_DEU_C_13.flac
# exporting 0124_DEU_C_14.flac
# exporting 0124_DEU_C_15.flac
# exporting 0124_DEU_C_16.flac
# exporting 0124_DEU_C_17.flac
# exporting 0124_DEU_C_18.flac
# exporting 0124_DEU_C_19.flac
# exporting 0124_DEU_C_20.flac
# exporting 0124_DEU_C_21.flac
# exporting 0124_DEU_C_22.flac
# exporting 0124_DEU_C_23.flac
# exporting 0124_DEU_C_24.flac
# exporting 0124_DEU_C_25.flac
# exporting 0124_DEU_C_26.flac
# exporting 0124_DEU_C_27.flac
# exporting 0124_DEU_C_28.flac
# exporting 0124_DEU_C_29.flac
# exporting 0124_DEU_C_30.flac
# exporting 0124_DEU_C_31.flac
# exporting 0124_DEU_C_32.flac
# exporting 0124_DEU_C_33.flac
# exporting 0124_DEU_C_34.flac
# exporting 0124_DEU_C_35.flac
# exporting 0124_DEU_C_36.flac
# exporting 0124_DEU_C_37.flac
# exporting 0124_DEU_C_38.flac
# exporting 0124_DEU_C_39.flac
# exporting 0124_DEU_C_40.flac
# exporting 0124_DEU_C_41.flac
# exporting 0124_DEU_C_42.flac
# exporting 0124_DEU_C_43.flac
# exporting 0124_DEU_C_44.flac
# exporting 0124_DEU_C_45.flac
# exporting 0124_DEU_C_46.flac
# File already exist. So just removing
# File already exist. So just removing
# exporting 0110_DEU_C_0.flac
# exporting 0110_DEU_C_1.flac
# exporting 0110_DEU_C_2.flac
# exporting 0110_DEU_C_3.flac
# exporting 0110_DEU_C_4.flac
# exporting 0110_DEU_C_5.flac
# exporting 0110_DEU_C_6.flac
# exporting 0110_DEU_C_7.flac
# exporting 0110_DEU_C_8.flac
# exporting 0110_DEU_C_9.flac
# exporting 0110_DEU_C_10.flac
# exporting 0110_DEU_C_11.flac
# exporting 0110_DEU_C_12.flac
# exporting 0110_DEU_C_13.flac
# exporting 0110_DEU_C_14.flac
# exporting 0110_DEU_C_15.flac
# exporting 0110_DEU_C_16.flac
# exporting 0110_DEU_C_17.flac
# exporting 0110_DEU_C_18.flac
# exporting 0110_DEU_C_19.flac
# exporting 0110_DEU_C_20.flac
# exporting 0110_DEU_C_21.flac
# exporting 0110_DEU_C_22.flac
# exporting 0110_DEU_C_23.flac
# exporting 0110_DEU_C_24.flac
# exporting 0110_DEU_C_25.flac
# exporting 0110_DEU_C_26.flac
# exporting 0110_DEU_C_27.flac
# exporting 0110_DEU_C_28.flac
# exporting 0110_DEU_C_29.flac
# exporting 0110_DEU_C_30.flac
# exporting 0110_DEU_C_31.flac
# File already exist. So just removing
# File already exist. So just removing
# exporting 0208_DEU_C_0.flac
# exporting 0208_DEU_C_1.flac
# exporting 0208_DEU_C_2.flac
# exporting 0208_DEU_C_3.flac
# exporting 0208_DEU_C_4.flac
# exporting 0208_DEU_C_5.flac
# exporting 0208_DEU_C_6.flac
# exporting 0208_DEU_C_7.flac
# exporting 0208_DEU_C_8.flac
# exporting 0208_DEU_C_9.flac
# exporting 0208_DEU_C_10.flac
# exporting 0208_DEU_C_11.flac
# exporting 0208_DEU_C_12.flac
# exporting 0208_DEU_C_13.flac
# exporting 0208_DEU_C_14.flac
# exporting 0208_DEU_C_15.flac
# exporting 0208_DEU_C_16.flac
# exporting 0208_DEU_C_17.flac
# exporting 0208_DEU_C_18.flac
# exporting 0208_DEU_C_19.flac
# exporting 0208_DEU_C_20.flac
# exporting 0208_DEU_C_21.flac
# exporting 0208_DEU_C_22.flac
# exporting 0208_DEU_C_23.flac
# exporting 0208_DEU_C_24.flac
# exporting 0208_DEU_C_25.flac
# exporting 0208_DEU_C_26.flac
# exporting 0208_DEU_C_27.flac
# exporting 0208_DEU_C_28.flac
# exporting 0208_DEU_C_29.flac
# exporting 0208_DEU_C_30.flac
# exporting 0208_DEU_C_31.flac
# exporting 0208_DEU_C_32.flac
# exporting 0208_DEU_C_33.flac
# exporting 0208_DEU_C_34.flac
# exporting 0208_DEU_C_35.flac
# exporting 0208_DEU_C_36.flac
# exporting 0208_DEU_C_37.flac
# exporting 0208_DEU_C_38.flac
# exporting 0208_DEU_C_39.flac
# File already exist. So just removing
# File already exist. So just removing
